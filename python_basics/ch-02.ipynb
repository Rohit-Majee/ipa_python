# %%
a = 1
id(1)
# Out:
# 140728260535416

# %%
id(a)
# Out:
# 140728260535704

# %%
b = 256
id(b)
# Out:
# 140728260543576

# %%
c = 257
id(c)
# Out:
# 1500657743792

# %%
id(c)
# Out:
# 1500657743792

# %%
a = -2.0j + 35
type(a)
# Out:
# complex

# %%
a
# Out:
# (35-2j)

# %%
complex()
# Out:
# 0j

# %%
bool()
# Out:
# False

# %%
s = "hello"
id(s)
# Out:
# 1500654528976

# %%
type(s)
# Out:
# str

# %%
str()
# Out:
# ''

# %%
s = "Python is a programming language"

# %%
s.upper()
# Out:
# 'PYTHON IS A PROGRAMMING LANGUAGE'

# %%
s.capitalize()
# Out:
# 'Python is a programming language'

# %%
s.title()
# Out:
# 'Python Is A Programming Language'

# %%
s.isupper()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
s.count('m')
# Out:
# 2

# %%
s.replace('Python', "Java")
# Out:
# 'Java is a programming language'

# %%
s.split("is")
# Out:
# ['Python ', ' a programming language']

# %%
s1 = "  hello   "

# %%
s1.strip()
# Out:
# 'hello'

# %%
s1.lstrip()
# Out:
# 'hello   '

# %%
s1.rstrip()
# Out:
# '  hello'

# %%
s.replace(" ", '')
# Out:
# 'Pythonisaprogramminglanguage'

# %%
l1 = [1,2,3,4,5]
type(l1)
# Out:
# list

# %%
l1.append(22)
l1
# Out:
# [1, 2, 3, 4, 5, 22]

# %%
l1.extend([23,24])
l1
# Out:
# [1, 2, 3, 4, 5, 22, 23, 24]

# %%
l1.insert(2,5)
l1
# Out:
# [1, 2, 5, 3, 4, 5, 22, 23, 24]

# %%
l1.remove(5)
l1
# Out:
# [1, 2, 3, 4, 5, 22, 23, 24]

# %%
l1.pop()
l1
# Out:
# [1, 2, 3, 4, 5, 22, 23]

# %%
l1.append(22)
l1
# Out:
# [1, 2, 3, 4, 5, 22, 23, 22]

# %%
l1.index(22)
# Out:
# 5

# %%
l1.count(22)
# Out:
# 2

# %%
l1.sort(reverse=True)
l1
# Out:
# [23, 22, 22, 5, 4, 3, 2, 1]

# %%
l1.reverse()
l1
# Out:
# [1, 2, 3, 4, 5, 22, 22, 23]

# %%
t1 = (1,2,3,4)
t1
# Out:
# (1, 2, 3, 4)

# %%
t1.count(2)
# Out:
# 1

# %%
print(dir(tuple))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
d1 = {'a':1 , 'b':2 , 'c':3}
d1
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d1["d"] = 4
d1
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
d1['a']=9
d1
# Out:
# {'a': 9, 'b': 2, 'c': 3, 'd': 4}

# %%
d1.values()
# Out:
# dict_values([9, 2, 3, 4])

# %%
d1.items()
# Out:
# dict_items([('a', 9), ('b', 2), ('c', 3), ('d', 4)])

# %%
d1.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %%
d1.get("a")
# Out:
# 9

# %%
d1.pop("d")
d1
# Out:
# {'a': 9, 'b': 2, 'c': 3}

# %%
s1 = set()

# %%
s1.add(2)
s1.add(3)
s1.add(4)
s1.add(2)
s1
# Out:
# {2, 3, 4, 5, 6, 8}

# %%
s1
# Out:
# {2, 3, 4, 5, 6, 8}

# %%
s2 = s1.copy()

# %%
s2.add(1)
s2
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
s1
# Out:
# {2, 3, 4, 5, 6, 8}

# %%
s1.remove(8)
s1
# Out:
# {2, 3, 4, 5, 6}

# %%
s1.discard(8)

# %%
s1.pop()
s1
# Out:
# {3, 4, 5, 6}

# %%
2 and 3
# Out:
# 3

# %%
3 and 2
# Out:
# 2

# %%
bin(10)
# Out:
# '0b1010'

# %%
hex(10)
# Out:
# '0xa'

# %%
2 & 3
# Out:
# 2

# %%
2 | 3
# Out:
# 3

# %%
20 ^ 30
# Out:
# 10

# %%
bin(0b1001 << 1)
# Out:
# '0b10010'

# %%
r = [1,2,3]
s = r
t = [1,2,3]

print(r is s)
print(r is t)
print(r is not t)
# Out:
# True
# False
# True

# %%
#1
a = eval(input("Enter a number : "))
if (a%3==0 and a%5==0):
    print(a)
# Out:
# 30

# %%
#2
age = eval(input("enter age: "))
if (age>= 18 and age<=25):
    print("Eligible for vote")
# Out:
# Eligible for vote

# %%
#3
num = eval(input("enter num: ")) 
if num < 0:
    print("negetive")
else:
    print("positive")
# Out:
# negetive

# %%
#4
marks = eval(input("Enter marks : "))

if marks>=90:
    print("A")
elif marks>=75:
    print("B")
elif marks>=60:
    print("C")
elif marks< 60:
    print("Fail")
# Out:
# A

# %%
#5
ch = str(input("enter value: "))

if ch.isupper():
    print("Upper")
elif ch.islower():
    print("Lower")
elif ch.isdigit():
    print("digit")
else:
    print("special")
# Out:
# digit

# %%
#6
exp = int(input("Enter exp: "))
rate = int(input("Enter rate: "))

if exp >= 5:
    if rate >= 4:
        print("20% bonus")
    else:
        print("10% bonus")

else:
    print("no bonus")
# Out:
# no bonus

# %%
#7
num = int(input("Enter a number : "))

if num >= 0:
    if num%2 == 0:
        print("even")
    else:
        print("odd")
else:
    print("negative")
# Out:
# odd

# %%
#8
pin = 909
balance = 9000
userpin = eval(input("Enter the pin: "))

if userpin == pin:
    w_amount = eval(input("Enter the withdraw amount: "))

    if balance >= w_amount:
        print("Transaction success")
    else:
        print("Balance insufficient")
else:
    print("wrong pin")
# Out:
# Balance insufficient

# %%
s3 = "hello"
s3[::2]
# Out:
# 'hlo'

# %%
st = ('indore','pune','goa','delhi')
st[-4:-1:-1]
# Out:
# ()

# %%
# Out:
# list
