# %%
#1
i = 1
while i<=100:
    if '7' in str(i):
        print(i, end=",")
    i+=1
# Out:
# 7,17,27,37,47,57,67,70,71,72,73,74,75,76,77,78,79,87,97,

# %%
#2
num = int(input("Enter a number: "))
temp = num
digit = 0
while num>0:
    rem = num % 10
    digit = digit * 10 + rem
    num = num // 10 

if digit > temp :
    print("original is smaller")
else:
    print("original is bigger")
# Out:
# original is smaller

# %%
#3
num = int(input("Enter a number: "))
total = 0
while num > 0:
    rem = num % 10
    total = total + rem
    num = num // 10

print(total)
# Out:
# 6

# %%
#4
even_count = 0
odd_count = 0
num = int(input("Enter a number: "))

while num > 0:
    rem = num % 10
    if rem % 2 == 0:
        even_count += 1
    else:
        odd_count += 1
    num = num // 10

print("even_count :", even_count)
print("odd_count :", odd_count)
# Out:
# even_count : 1
# odd_count : 2

# %%
#5
num = int(input("Enter a number: "))
temp = num
digit = 0
while num>0:
    rem = num % 10
    digit = digit * 10 + rem
    num = num // 10 

if temp == digit:
    print("pallindrom")
else:
    print("not pallindrom")
# Out:
# not pallindrom

# %%
#6
password = 12334
name = "abc"
count = 3
while count > 0:

    user_name = input("Enter the name: ")
    user_password = eval(input("Enter the password: "))
    if user_password == password and user_name == name:
        print("Correct pin")
        break
    else:
        count -= 1
        print("incorrect name or password, try again!!")
        print(f"Attempts left : {count}")


if count <= 0:
    print("you 3 attempts are over!!")
# Out:
# incorrect name or password, try again!!
# Attempts left : 2
# incorrect name or password, try again!!
# Attempts left : 1
# incorrect name or password, try again!!
# Attempts left : 0
# you 3 attempts are over!!

# %%
#7
num = int(input("Enter a number: "))
digit = int(input("Enter a number: "))
count = 0 
while num>0:
    rem = num % 10
    if rem == digit:
        count +=1
    num = num // 10 

print(f"the digit {digit} present : {count} times")
# Out:
# the digit 3 present : 4 times

# %%
#8
total = 0

while total <= 100:
    num = eval(input("Enter a number: "))
    total += num

print("your total excceded 100")
print("your total:",total)
# Out:
# your total excceded 100
# your total: 120

# %% [markdown]
# ## Functions

# %%
def sum():
    a = int(input())
    b = int(input())
    return a+b
    

sum()
# Out:
# 6
# hello

# %%
def hello():
    return "hello!!"
var = hello()
print(var)
# Out:
# hello!!

# %%
#4 with function
def count(num):
    even_count = 0
    odd_count = 0
    
    while num > 0:
        rem = num % 10
        if rem % 2 == 0:
            even_count += 1
        else:
            odd_count += 1
        num = num // 10
    
    return even_count,odd_count

even_count,odd_count = count(545)
print("even_count :", even_count)
print("odd_count :", odd_count)
# Out:
# even_count : 1
# odd_count : 2

# %%
#5 with function
def isPallinderom(num):
    temp = num
    digit = 0
    while num>0:
        rem = num % 10
        digit = digit * 10 + rem
        num = num // 10 

    if temp == digit:
        return "pallindrom"
    else:
        return "not pallindrom"

print(isPallinderom(212))
# Out:
# pallindrom

# %%
import logging

logging.basicConfig(
    filename="ch-03.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# %% [markdown]
# # for loop questions

# %%
#1
def count_vowel(s:str) -> str:
    """
    Count the number of vowels in a given string.
    Parameters:
        s (str): Input string
    Returns:
        int: Total number of vowels in the string.
    """
    logging.info("Counting vowels in the string")
    vowel_count = 0
    for ch in s:
        if ch in 'aeiou':
            vowel_count+=1

    logging.info(f"vowel count for {s} : {vowel_count}")
    return vowel_count

s1 = "abcde"
count_vowel(s1)
# Out:
# 2

# %%
#2
from typing import Dict
def frequency_count(s:str)->Dict[str:int]:
    """
    Count the number of vowels in a given string.
    Parameters:
        s (str): Input string
    Returns:
        Dict: frequency of each character in a string.
    """
    logging.info("Counting characters in the string")
    
    freq = {}
    
    for ch in s:
        if ch in freq:
            freq[ch] += 1
        else:
            freq[ch] = 1
    logging.info(f"The frequency of each charater in {s} : {freq}")
    return freq

s2 = "aaabbc"
frequency_count(s2)
# Out:
# {'a': 2, 'c': 3, 'b': 1}

# %%
#3
from typing import List

def find_second_largest(nums: List[int]) -> int:
    """
    Find the second largest element in a given list.
    
    Parameters:
        nums (list): Input list of integers
        
    Returns:
        int: Second largest element in the list.
    """
    logging.info("Finding second largest element in the list")
    
    if len(nums) < 2:
        logging.error("List must contain at least two elements")

    largest = float('-inf')
    second_largest = float('-inf')

    for num in nums:
        if num > largest:
            second_largest = largest
            largest = num
        elif num > second_largest and num != largest:
            second_largest = num


    logging.info(f"Second largest element in {nums} : {second_largest}")
    return second_largest


nums1 = [10, 20, 4, 45, 99]
find_second_largest(nums1)
# Out:
# 45

# %% [markdown]
# # list comprihenssion

# %%
s = "Python is very very easy language"

oup = {(i.lower(),len(i)) for i in s.split()}

print(oup)
# Out:
# {('python', 6), ('is', 2), ('very', 4), ('language', 8), ('easy', 4)}

# %%
s1 = "Hai HeLLO"
oup = {i:ord(i) for i in s1 if i.isupper()}
print(oup)
# Out:
# {'H': 72, 'L': 76, 'O': 79}
